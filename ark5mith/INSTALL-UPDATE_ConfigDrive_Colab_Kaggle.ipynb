# %% [markdown]
# <a href="https://colab.research.google.com/github/ark5mith/stable-diffusion-webui-colab/blob/community/ark5mith/INSTALL-UPDATE_ConfigDrive_Colab_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install and update the WEBUI to Google Drive storage only.
#
# Multiple account only need to install once when using Shared Drive.
#
# v1 Based on Camenduru GDrive Notebook 27/03/2023
# https://github.com/camenduru/stable-diffusion-webui-colab/tree/drive
#
#
# [README](https://github.com/ark5mith/stable-diffusion-webui-colab/blob/community/ark5mith/readme.md)
#
# ---
#
# ##You can disable GPU during installation, as GPU not required
# ---
# #**AFTER** modifying customization (Installation path, Models, Extension, etc), Click on **Runtime>Run All** or use shortcut CTRL+F9 to start, or use the triangle button ![image.png](data:image/png;base64,...) on left side to minimize and click the single play button ![image.png](data:image/png;base64,...)
# ---
# v1.1 Update 04/04/2023 from main branch
#
# v1.13 Update 06/04/2023 install_path, easier model and extension download
#
# ---
#
# [**LATEST RUN**](https://colab.research.google.com/github/ark5mith/stable-diffusion-webui-colab/blob/community/ark5mith/RUN_ConfigDrive_Colab_Kaggle.ipynb) | [**LATEST INSTALL**](https://colab.research.google.com/github/ark5mith/stable-diffusion-webui-colab/blob/community/ark5mith/INSTALL-UPDATE_ConfigDrive_Colab_Kaggle.ipynb) |
# [*OLD v1.1 RUN*](https://colab.research.google.com/drive/1HGSyMkIi2aQzDgJe_68EelpV0W3wmuo_?usp=sharing) | [*OLD v1.1 INSTALL*](https://colab.research.google.com/drive/1mPw7WjKz16LTOpKCxFdLs_H5_CmPPiaJ?usp=sharing) |
# [*OLD v1 RUN* (NO NGROK)](https://colab.research.google.com/drive/1BvOr-K5YS_YQ06A0wm0I21I47ohJlcCv?usp=sharing) | [*OLD v1 RUN* (WITH NGROK)](https://colab.research.google.com/drive/1oNBDLXGHt5s1YgMPfMT42aZvXKpDObTb?usp=sharing) | [*OLD v1 INSTALL*](https://colab.research.google.com/drive/16_bT6P2_MKH8DFLhCWP5KKB6PXdmmppQ?usp=sharing)
#
# [**KAGGLE VERSION**](https://www.kaggle.com/code/roykent/stablediffusionwebui-configured/)

# %%
# @title #**[MODELS](https://huggingface.co/models?other=stable-diffusion) to Download**
modelsdl = {
    #"anything-v4.0-pruned.ckpt": "https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt",
    "anything-v4.5-pruned.ckpt": "https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.5-pruned.ckpt",
    "anything-v4.5-pruned.vae.pt": "https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.0.vae.pt",
    "SukiyakiMix-v1.0-fp32.safetensors": "https://huggingface.co/Vsukiyaki/SukiyakiMix-v1.0/resolve/main/SukiyakiMix-v1.0-fp32.safetensors",
    "mdjrny-v4.ckpt": "https://huggingface.co/ckpt/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt",
    "dreamlike-photoreal-2.0.safetensors": "https://huggingface.co/ckpt/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors",
    "OpenAnimeJourney.ckpt": "https://huggingface.co/ckpt/OpenAnimeJourney/resolve/main/OpenAnimeJourney.ckpt",
    "Anything-V3.0.vae.pt": "https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt",
    "AOM3.safetensors": "https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3.safetensors",
    "AOM3A1.safetensors": "https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A1.safetensors",
    "AOM3A2.safetensors": "https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A2.safetensors",
    "AOM3A3.safetensors": "https://huggingface.co/ckpt/OrangeMixs/resolve/main/AOM3A3.safetensors",
    "orangemix.vae.pt": "https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt",
}

# %% [markdown]
# "model_name.extension": "model_download_link", "model_name.extension": "model_download_link"
#
# you can add `#` in front to disable without deleting the codes

# %%
# @title  #**[EXTENSIONS](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions)  to Download**

extensionsdl=[
  'https://github.com/Interpause/auto-sd-paint-ext',
  'https://github.com/DominikDoom/a1111-sd-webui-tagcomplete',
  'https://github.com/nonnonstop/sd-webui-3d-open-pose-editor',
  'https://github.com/AbdullahAlfaraj/Auto-Photoshop-StableDiffusion-Plugin'
]

# %% [markdown]
#  Add `#` in front to disable without deleting the codes
#
#  Use comma to separate and use single quote for each link.
#
#  To uninstall, you need to manually delete the files in google drive

# %%
#@title #**INSTALL PATH** Customization
#@markdown replace /content/drive/Shareddrives/COLAB0 with your drive like /content/drive/MyDrive

#@markdown after replacing like that, WEBUI will be Installed on a folder /content/drive/MyDrive/stable-diffusion-webui

from google.colab import drive
drive.mount('/content/drive')

install_path="/content/drive/Shareddrives/COLAB0" # @param {type:"string"}
# @markdown &nbsp;
#output_path="/content"
# @markdown &nbsp;

#@markdown *below might not be required since it could be overwritten in Run notebook*
output_path="/content/drive/Shareddrives/OUTPUT"  # @param {type:"string"}
    #original webui_setting https://github.com/2575044704/sd-configs4.git
    
webui_settings = 'https://github.com/ark5mith/sd-configs' # @param {type:"string"}
setting_file = '/content/drive/Shareddrives/COLAB0/configs/config.json' # @param {type:"string"}
ui_config_file = '/content/drive/Shareddrives/COLAB0/configs/ui-config.json' # @param {type:"string"}

from pathlib import Path
import os
import time
import re

linkHypernetworksDir=False # 链接 hypernetworks 目录到输出目录 如果需要训练 hypernetworks 时建议开启
linkEmbeddingsDir=False # 链接 embeddings 目录到输出目录 如果需要训练 embeddings 时建议开启
linkTextual_inversionDir=False # 链接 textual_inversion 目录到输出目录 如果需要保存训练过程的产出文件时建议开启


os.environ['install_path'] = install_path
os.environ['output_path'] = output_path
os.environ['webui_settings'] = webui_settings
# Out:
# Mounted at /content/drive

# %%
#@title #**DEFINITION**
#@markdown Leave as it is. If it doesn't show anything but ✔ , then it is done 
def link_dir():
    # 链接输出目录 因为sd被部署在了stable-diffusion-webui目录，运行结束后为了方便下载就只有outputs目录放在output_path/目录下
    # !mkdir -p $output_path/outputs
    # !rm -rf $install_path/stable-diffusion-webui/outputs
    # !ln -s -r $output_path/outputs $install_path/stable-diffusion-webui/ # 输出目录
    # !mkdir -p $output_path/log
    # !rm -rf $install_path/stable-diffusion-webui/log
    # !ln -s -r $output_path/log $install_path/stable-diffusion-webui/
    # 链接 hypernetworks 目录
    if linkHypernetworksDir:
        # !rm -rf $install_path/stable-diffusion-webui/models/hypernetworks
        # !mkdir -p $output_path/hypernetworks
        # !ln -s -r $output_path/hypernetworks $install_path/stable-diffusion-webui/models/
    # 链接 embeddings 目录
    if linkEmbeddingsDir:
        # !rm -rf $install_path/stable-diffusion-webui/embeddings
        # !mkdir -p $output_path/embeddings
        # !ln -s -r $output_path/embeddings $install_path/stable-diffusion-webui/
    # 链接训练输出目录 文件夹链接会导致功能不能用
    if linkTextual_inversionDir:
        # !rm -rf $install_path/stable-diffusion-webui/textual_inversion
        # !mkdir -p $output_path/textual_inversion/
        # !ln -s -r $output_path/textual_inversion $install_path/stable-diffusion-webui/
        
def use_config():
    # %cd $install_path/stable-diffusion-webui
    # !mkdir -p tmp
    # %cd tmp
    # !git clone $webui_settings sd-configs
    # !cp -rf sd-configs/dist/* $install_path/stable-diffusion-webui
    
def start():
    # %cd $install_path/stable-diffusion-webui
    # !python launch.py --skip-torch-cuda-test --no-half-vae --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple
    #!python launch.py --share --xformers --enable-insecure-extension-access --theme dark --gradio-queue
        
def main():
    use_config()
    link_dir()
    start()

# %%
#@title #**DEPENDENCIES**

# %cd /content
# %env PYTHONDONTWRITEBYTECODE=1
# !apt-get -y install -qq aria2

# STABLE DIFFUSION
# !git clone -b v2.0 https://github.com/camenduru/stable-diffusion-webui $install_path/stable-diffusion-webui
# !git -C $install_path/stable-diffusion-webui checkout -f v2.1
# !git -C $install_path/stable-diffusion-webui reset --hard
# !git -C $install_path/stable-diffusion-webui pull origin v2.1

# EMBED
# !git clone https://huggingface.co/embed/negative $install_path/stable-diffusion-webui/embeddings/negative
# !git clone https://huggingface.co/embed/lora $install_path/stable-diffusion-webui/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d $install_path/stable-diffusion-webui/models/ESRGAN -o 4x-UltraSharp.pth


# SCRIPT AND EXTENSION
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O $install_path/stable-diffusion-webui/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui $install_path/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui

# !rm -rf $install_path/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser

# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface

# !rm -rf $install_path/extensions/sd-civitai-browser
# !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser $install_path/stable-diffusion-webui/extensions/sd-civitai-browser

# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/drive/Shareddrives/COLAB0/stable-diffusion-webui/extensions/sd-webui-additional-networks
# !git clone https://github.com/Mikubill/sd-webui-controlnet $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet
# !git clone https://github.com/camenduru/openpose-editor $install_path/stable-diffusion-webui/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-webui-depth-lib $install_path/stable-diffusion-webui/extensions/sd-webui-depth-lib
# !git clone https://github.com/hnmr293/posex $install_path/stable-diffusion-webui/extensions/posex
# !git clone https://github.com/camenduru/sd-webui-tunnels $install_path/stable-diffusion-webui/extensions/sd-webui-tunnels
# !git clone https://github.com/etherealxx/batchlinks-webui $install_path/stable-diffusion-webui/extensions/batchlinks-webui
# !git clone https://github.com/camenduru/stable-diffusion-webui-catppuccin $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon $install_path/stable-diffusion-webui/extensions/a1111-sd-webui-locon

#@markdown Uncheck this if it is first installation
ExtUpdate =False # @param {type:"boolean"}

for ext_url in extensionsdl:
    ext_name = ext_url.split("/")[-1]
    ext_path = os.path.join(install_path, "stable-diffusion-webui", "extensions", ext_name)

    if ExtUpdate:
        if os.path.isdir(ext_path):
            print(f"Updating {ext_name}")
            os.system(f"git -C {ext_path} reset --hard")
            os.system(f"git -C {ext_path} pull")
        else:
            print(f"Extension {ext_name} is not installed, cannot update. Installing")
            os.system(f'git clone {ext_url} {ext_path}')        
    else:
        if not os.path.isdir(ext_path):
            print(f"Installing {ext_name}")
            os.system(f'git clone {ext_url} {ext_path}')
        else:
            print(f"Extension {ext_name} is already installed. Updating")
            os.system(f"git -C {ext_path} reset --hard")
            os.system(f"git -C {ext_path} pull")

# %cd $install_path/stable-diffusion-webui

# RESET & UPDATE
# !git -c $install_path/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui pull
# !git -c $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser pull
# !git -c $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface pull
# !git -c $install_path/stable-diffusion-webui/extensions/sd-civitai-browser reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/sd-civitai-browser pull
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-additional-networks reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-additional-networks pull
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet pull
# !git -c $install_path/stable-diffusion-webui/extensions/openpose-editor reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/openpose-editor pull
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-depth-lib reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-depth-lib pull
# !git -c $install_path/stable-diffusion-webui/extensions/posex reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/posex pull
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-tunnels reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/sd-webui-tunnels pull
# !git -c $install_path/stable-diffusion-webui/extensions/batchlinks-webui reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/batchlinks-webui pull
# !git -c $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/stable-diffusion-webui-catppuccin pull
# !git -c $install_path/stable-diffusion-webui/extensions/a1111-sd-webui-locon reset --hard
# !git -c $install_path/stable-diffusion-webui/extensions/a1111-sd-webui-locon pull

# CONTROL NET
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_canny-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_canny-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_depth-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_depth-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_hed-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_hed-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_mlsd-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_mlsd-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_normal-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_normal-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_openpose-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_openpose-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_scribble-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_scribble-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_seg-fp16.safetensors -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o control_seg-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose -o hand_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose -o body_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/midas -o dpt_hybrid-midas-501f0c75.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_large_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_tiny_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/hed -o network-bsds500.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer -o upernet_global_small.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_style_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_sketch_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_seg_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_openpose_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_keypose_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_depth_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_color_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_canny_sd14v1.pth -d $install_path/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd14v1.pth


# MODEL LOOP SCRIPT
# loop through URLs and download the files
#In this code, the model_files dictionary contains the URLs and output file names for each file to be downloaded. The loop then iterates through this dictionary and constructs a command string for each URL and file name, and executes the command using the !{command} syntax.
modelsdl_aria = "aria2c --console-log-level=error -c -x 16 -s 16 -k 1M"

for modelname, modelurl in modelsdl.items():
    print (f"Downloading {modelname}")
    download_cmd = f"{modelsdl_aria} {modelurl} -d {install_path}/stable-diffusion-webui/models/Stable-diffusion -o {modelname}"
    os.system(download_cmd)


#setting extra

# !sed -i -e 's/    start()/    #start()/g' $install_path/stable-diffusion-webui/launch.py
# !sed -i -e 's/checkout {commithash}/checkout --force {commithash}/g' $install_path/stable-diffusion-webui/launch.py

print('All Done')
# Out:
# /content
# env: PYTHONDONTWRITEBYTECODE=1
# fatal: destination path '/content/drive/Shareddrives/COLAB0/stable-diffusion-webui' already exists and is not an empty directory.
# Updating files: 100% (200/200), done.
# Already on 'v2.1'
# Your branch is up to date with 'origin/v2.1'.
# HEAD is now at a9fed7c3 Merge pull request #8503 from mcmonkey4eva/filename-length-limit-fix
# From https://github.com/camenduru/stable-diffusion-webui
#  * branch              v2.1       -> FETCH_HEAD
# Already up to date.
# fatal: destination path '/content/drive/Shareddrives/COLAB0/stable-diffusion-webui/embeddings/negative' already exists and is not an empty directory.
# fatal: destination path '/content/drive/Shareddrives/COLAB0/stable-diffusion-webui/models/Lora/positive' already exists and is not an empty directory.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ...

# %%
#@title #**INSTALL**
print('Loading WEBUI. Wait until Done..')
main()
print('DONE. WEBUI Installed. Run the WEBUI with this notebook: https://colab.research.google.com/drive/1HGSyMkIi2aQzDgJe_68EelpV0W3wmuo_?usp=sharing')
# Out:
# Loading WEBUI. Wait until Done..
# /content/drive/Shareddrives/COLAB0/stable-diffusion-webui
# /content/drive/Shareddrives/COLAB0/stable-diffusion-webui/tmp
# fatal: destination path 'sd-configs' already exists and is not an empty directory.
# /content/drive/Shareddrives/COLAB0/stable-diffusion-webui
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Commit hash: a9fed7c364061ae6efb37f797b6b522cb3cf7aa2
# Installing requirements for Web UI
#
#
#
#
#
#
# [auto-sd-paint-ext] Commit hash: 272e184710b3a81ad1c742f199e30e176131854e
# [auto-sd-paint-ext] Auto-update disabled.
#
# ...
#
# [Auto-Photoshop-SD] Attempting auto-update...
# [Auto-Photoshop-SD] switch branch to extension branch.
# checkout_result: M	start_server.sh
# M	start_server_MacOS.sh
# Your branch is up to date with 'origin/master'.
#
# [Auto-Photoshop-SD] Current Branch.
# branch_result: * master
#
# [Auto-Photoshop-SD] Fetch upstream.
# fetch_result:
# [Auto-Photoshop-SD] Pull upstream.
# ...

# %% [markdown]
# Big thanks to Camenduru 💌 for always up to date and reliable colab
#
# Thanks to [ChatGPT](https://chat.openai.com/chat) for providing 24/7 assistance. You can look how independent i'm in [using ChatGPT, shared by ShareGPT](https://sharegpt.com/c/Z8KX0c4)
#
# Special thanks ✌ [ddPn08](https://github.com/ddpn08/) and [viyiviyi](https://github.com/viyiviyi) for their inspiring notebook
