# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/stable-diffusion-webui-colab/blob/main/v1.9/refslave_v2_webui_colab.ipynb)

# %% [markdown]
# # 🚨 Important: This Colab Notebook is obsolete! Please use https://github.com/camenduru/stable-diffusion-webui-colab `lite` `stable` `nightly` versions for the latest updated Colab Notebooks.
