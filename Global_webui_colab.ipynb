# %%
#@title Customize your settings then run the cell { vertical-output: true }
#@markdown Choose a model
Model = "Stable Diffusion 1.5" #@param ["7th Layer", "8528 Diffusion", "A Certain Model", "A Certain Thing", "A Certainty", "Abyss Orange Mix 2", "All In One Pixel Model", "Analog Diffusion", "Anything V3", "Anything V4", "Anything Gape", "Arcane Diffusion 3", "Babes Blend", "Berry Mix 1.5", "Cafe Instagram v6", "Cinematic Diffusion", "Comic Diffusion v2", "Comics Blend", "Complex Lineart", "Cool Japan Diffusion 2.1", "Counterfeit v2.0", "Cyberpunk Anime Diffusion", "Dream Like Sam Kuvshino", "Dreamlike Diffusion 1", "Dreamlike Photoreal 2", "DucHaitenAIArt v1.1", "Eimis Anime Diffusion 1", "Elldreth's Lucid Mix v10", "Elysium Anime 2", "F222", "Food Crit", "Grapefruit", "HasDX", "Hassan Blend 1.4", "Illustration Diffusion", "Inkpunk", "Izumi v1", "Knollingcase", "Midjourney v4", "Mo Di Diffusion", "Monstermash Any 3", "Open Anime Journey", "Open Journey v2", "Papercut Diffusion", "Photorealostic Fuen v1", "Pix2Pix", "Pony Diffusion 2", "Popup Book Diffusion", "Protogen v2.2", "Rando mix 3", "Riffusion v1", "RPG v4", "SamDoesArt Diffusion", "SamDoesSexy Blend", "Seek Art Mega v1", "Simpmaker 3k", "Stable Diffusion 1.4", "Stable Diffusion 1.5", "Stable Diffusion 1.5 Inpainting", "Stable Diffusion 2", "Stable Diffusion 2 Base", "Stable Diffusion 2 Depth", "Stable Diffusion 2 Inpainting", "Stable Diffusion 2.1", "Stable Diffusion 2.1 Base", "Synthwave Punk v2", "Uber Realistic v1", "Van Gogh Diffusion", "Vintedois Diffusion", "Waifu Diffusion", "Waifu Diffusion 1.4", "Woolitize", "Yiffy E18", "Yiffy Mix", "Yohan Diffusion"]
#@markdown Common negative embeddings
bad_artist = False #@param {type:"boolean"} 
bad_artist_anime = False #@param {type:"boolean"}
bad_hands_5 = False #@param {type:"boolean"}
bad_prompt = False #@param {type:"boolean"}
bad_prompt_version2 = False #@param {type:"boolean"}
#@markdown Common VAE
vae_ft_mse_840000_ema_pruned = False #@param {type:"boolean"}
Anything_V3_vae= False #@param {type:"boolean"}

## Common code

# !pip install -q https://github.com/camenduru/stable-diffusion-webui-colab/releases/download/0.0.16/xformers-0.0.16+814314d.d20230118-cp38-cp38-linux_x86_64.whl
# !pip install -q --pre triton

# !git clone -b v2.0 https://github.com/camenduru/stable-diffusion-webui
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O /content/stable-diffusion-webui/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
# !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
# %cd /content/stable-diffusion-webui

## Downloading requested model

if Model=="7th Layer":
    # !wget https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_layer/Abyss_7th_layer.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Abyss_7th_layer.ckpt
    # !wget https://huggingface.co/syaimu/7th_Layer/resolve/main/7th_anime_v3/7th_anime_v3_C.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/7th_anime_v3_C.safetensors
elif Model=="8528 Diffusion":
    # !wget https://huggingface.co/ckpt/8528-diffusion/resolve/main/8528d-final.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/8528d-final.ckpt
elif Model=="A Certain Model":
    # !wget https://huggingface.co/ckpt/ACertainModel/resolve/main/ACertainModel.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ACertainModel.ckpt
elif Model=="A Certain Thing":
    # !wget https://huggingface.co/ckpt/ACertainThing/resolve/main/ACertainThing.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ACertainThing.ckpt
elif Model=="A Certainty":
    # !wget https://huggingface.co/ckpt/ACertainty/resolve/main/ACertainty.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ACertainty.ckpt
elif Model=="Abyss Orange Mix 2":
    # !wget https://huggingface.co/ckpt/OrangeMixs/resolve/main/AbyssOrangeMix2_nsfw.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix2_nsfw.safetensors
    # !wget https://huggingface.co/ckpt/OrangeMixs/resolve/main/AbyssOrangeMix2_hard.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix2_hard.safetensors
    # !wget https://huggingface.co/ckpt/OrangeCocoaMix/resolve/main/OrangeCocoaMix2_hard.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/OrangeCocoaMix2_hard.safetensors
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/AbyssOrangeMix2_nsfw.vae.pt
elif Model=="All In One Pixel Model":
    # !wget https://huggingface.co/ckpt/All-In-One-Pixel-Model/resolve/main/Public-Prompts-Pixel-Model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Public-Prompts-Pixel-Model.ckpt
elif Model=="Analog Diffusion":
    # !wget https://huggingface.co/ckpt/Analog-Diffusion/resolve/main/analog-diffusion-1.0.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/analog-diffusion-1.0.ckpt
elif Model=="Anything V3":
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0-pruned.ckpt
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0-pruned.vae.pt
elif Model=="Anything V4":
    # !wget https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.0-pruned.ckpt
    # !wget https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.5-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.5-pruned.ckpt
    # !wget https://huggingface.co/ckpt/anything-v4.0/resolve/main/anything-v4.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything-v4.5-pruned.vae.pt
elif Model=="Anything Gape":
    # !wget https://huggingface.co/ckpt/AnyGape/resolve/main/AnythingGape-fp16.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/AnythingGape-fp16.ckpt
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/AnythingGape-fp16.vae.pt
elif Model=="Arcane Diffusion 3":
    # !wget https://huggingface.co/ckpt/Arcane-Diffusion/resolve/main/arcane-diffusion-v3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/arcane-diffusion-v3.ckpt
elif Model=="Babes Blend":
    # !wget https://huggingface.co/ckpt/babes/resolve/main/babes_11.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/babes_11.safetensors
elif Model=="Berry Mix 1.5":
    # !wget https://huggingface.co/ckpt/rbm/resolve/main/rbm.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/rbm.ckpt
elif Model=="Cafe Instagram v6":           
    # !wget https://huggingface.co/ckpt/cafe-instagram-sd-1-5-v6/resolve/main/instagram-latest-plus-clip-v6e1_50000.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/instagram-latest-plus-clip-v6e1_50000.safetensors
elif Model=="Cinematic Diffusion":              
    # !wget https://huggingface.co/ckpt/Cinematic-Diffusion/resolve/main/syberart.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/syberart.ckpt
elif Model=="Comic Diffusion v2":
    # !wget https://huggingface.co/ckpt/Comic-Diffusion/resolve/main/comic-diffusion-V2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/comic-diffusion-V2.ckpt
elif Model=="Comics Blend":
    # !wget https://huggingface.co/ckpt/comicsblend/resolve/main/comicsblend_V1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/comicsblend_V1.ckpt
elif Model=="Complex Lineart":
    # !wget https://huggingface.co/ckpt/Complex-Lineart/resolve/main/ComplexLA%20Style.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/ComplexLA%20Style.ckpt
elif Model=="Cool Japan Diffusion 2.1":
    # !wget https://huggingface.co/ckpt/cool-japan-diffusion-2-1-0/resolve/main/v2-1-0.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1-0.ckpt
    # !wget https://huggingface.co/ckpt/cool-japan-diffusion-2-1-0/raw/main/v2-1-0.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1-0.yaml
elif Model=="Counterfeit v2.0":
    # !wget https://huggingface.co/ckpt/Counterfeit-V2.0/resolve/main/Counterfeit-V2.0fp16.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/Counterfeit-V2.0fp16.safetensors
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt
elif Model=="Cyberpunk Anime Diffusion":
    # !wget https://huggingface.co/ckpt/Cyberpunk-Anime-Diffusion/resolve/main/Cyberpunk-Anime-Diffusion.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Cyberpunk-Anime-Diffusion.ckpt
elif Model=="Dream Like Sam Kuvshino":
    # !wget https://huggingface.co/ckpt/dreamlikesamkuvshinov/resolve/main/dreamlikesamkuvshino.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/dreamlikesamkuvshino.safetensors
elif Model=="Dreamlike Diffusion 1":
    # !wget https://huggingface.co/ckpt/dreamlike-diffusion-1.0/resolve/main/dreamlike-diffusion-1.0.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/dreamlike-diffusion-1.0.ckpt
elif Model=="Dreamlike Photoreal 2":
    # !wget https://huggingface.co/ckpt/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/dreamlike-photoreal-2.0.safetensors
elif Model=="DucHaitenAIArt v1.1":
    # !wget https://huggingface.co/ckpt/DucHaitenAIart_v1.1a/resolve/main/DucHaitenAIart_v1.1a_emaonly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/DucHaitenAIart_v1.1a_emaonly.ckpt
    # !wget https://huggingface.co/ckpt/DucHaitenAIart_v2.0/resolve/main/DucHaitenAIart_v2.0-emaonly.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/DucHaitenAIart_v2.0-emaonly.safetensors
    # !wget https://huggingface.co/DucHaiten/DucHaitenDarkside/resolve/main/DucHaitenDarkside_v1.0.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/DucHaitenDarkside_v1.0.safetensors
elif Model=="Eimis Anime Diffusion 1":
    # !wget https://huggingface.co/ckpt/EimisAnimeDiffusion_1.0v/resolve/main/EimisAnimeDiffusion_1-0v.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/EimisAnimeDiffusion_1-0v.ckpt
elif Model=="Elldreth's Lucid Mix v10":
    # !wget https://huggingface.co/ckpt/elldrethSLucidMix_v10/resolve/main/elldrethSLucidMix_v10.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/elldrethSLucidMix_v10.ckpt
elif Model=="Elysium Anime 2":
    # !wget https://huggingface.co/ckpt/SD-Elysium-Model/resolve/main/Elysium_Anime_V2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Elysium_Anime_V2.ckpt
    # !wget https://huggingface.co/ckpt/SD-Elysium-Model/resolve/main/Elysium_Anime_V3.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/Elysium_Anime_V3.safetensors
    # !wget https://huggingface.co/ckpt/waifu-diffusion-v1-4/resolve/main/kl-f8-anime2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Elysium_Anime_V2.vae.pt
elif Model=="F222":
    # !wget https://huggingface.co/ckpt/f2/resolve/main/f2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/f2.ckpt
elif Model=="Food Crit":
    # !wget https://huggingface.co/ckpt/food-crit/resolve/main/food_crit.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/food_crit.ckpt
elif Model=="Grapefruit":
    # !wget https://huggingface.co/ckpt/grapefruit/resolve/main/grapefruit.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/grapefruit.safetensors
    # !wget https://huggingface.co/ckpt/grapefruit/resolve/main/grapefruit.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/grapefruit.vae.pt
elif Model=="HasDX":
    # !wget https://huggingface.co/ckpt/hasdx/resolve/main/hasdx_emaonly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/hasdx_emaonly.ckpt
elif Model=="Hassan Blend 1.4":
    # !wget https://huggingface.co/ckpt/hassanblend1.4/resolve/main/HassanBlend1.4-Pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/HassanBlend1.4-Pruned.ckpt
elif Model=="Illustration Diffusion":
    # !wget https://huggingface.co/ckpt/Illustration-Diffusion/resolve/main/hollie-mengert.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/hollie-mengert.ckpt
elif Model=="Inkpunk":
    # !wget https://huggingface.co/ckpt/Inkpunk-Diffusion/resolve/main/Inkpunk-Diffusion-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Inkpunk-Diffusion-v2.ckpt
elif Model=="Izumi v1":
    # !wget https://huggingface.co/ckpt/iz/resolve/main/izumi_01.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/izumi_01.ckpt
elif Model=="Knollingcase":
    # !wget https://huggingface.co/ckpt/knollingcase/resolve/main/knollingcase.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/knollingcase.ckpt
elif Model=="Midjourney v4":
    # !wget https://huggingface.co/ckpt/midjourney-v4-diffusion/resolve/main/mdjrny-v4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/mdjrny-v4.ckpt
elif Model=="Mo Di Diffusion":
    # !wget https://huggingface.co/ckpt/mo-di-diffusion/resolve/main/moDi-v1-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/moDi-v1-pruned.ckpt
elif Model=="Monstermash Any 3":
    # !wget https://huggingface.co/ckpt/monstermash_anyv3/resolve/main/monstermash4%2Banyv3.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/monstermash4%2Banyv3.safetensors
    # !wget https://huggingface.co/ckpt/monstermash_anyv3/resolve/main/monstermash6%2Banyv3.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/monstermash6%2Banyv3.safetensors
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0-pruned.vae.pt
elif Model=="Open Anime Journey":
    # !wget https://huggingface.co/ckpt/OpenAnimeJourney/resolve/main/OpenAnimeJourney.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/OpenAnimeJourney.ckpt
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt
elif Model=="Open Journey v2":
    # !wget https://huggingface.co/ckpt/openjourney-v2/resolve/main/openjourney-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/openjourney-v2.ckpt
elif Model=="Papercut Diffusion":
    # !wget https://huggingface.co/ckpt/Stable_Diffusion_PaperCut_Model/resolve/main/PaperCut_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/PaperCut_v1.ckpt
elif Model=="Photorealostic Fuen v1":
    # !wget https://huggingface.co/ckpt/photorealistic-fuen-v1/resolve/main/photorealistic-fuen-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/photorealistic-fuen-v1.ckpt
elif Model=="Pix2Pix":
    # !git clone https://github.com/Klace/stable-diffusion-webui-instruct-pix2pix /content/stable-diffusion-webui/extensions/stable-diffusion-webui-instruct-pix2pix
    # !wget https://huggingface.co/timbrooks/instruct-pix2pix/resolve/main/instruct-pix2pix-00-22000.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/instruct-pix2pix-00-22000.safetensors
elif Model=="Pony Diffusion 2":
    # !wget https://huggingface.co/ckpt/pony-diffusion-v2/resolve/main/pony-diffusion-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/pony-diffusion-v2.ckpt
elif Model=="Popup Book Diffusion":
    # !wget https://huggingface.co/ckpt/popupBook-diffusion/resolve/main/popupBook-diffusion-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/popupBook-diffusion-v1.ckpt
elif Model=="Protogen v2.2":
    # !wget https://huggingface.co/ckpt/Protogen_V2.2/resolve/main/Protogen_V2.2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Protogen_V2.2.ckpt
elif Model=="Rando mix 3":
    # !wget https://huggingface.co/ckpt/RandoMix3/resolve/main/RandoMix3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/RandoMix3.ckpt
    # !wget https://huggingface.co/ckpt/RandoMix3/resolve/main/RandoMix3.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/RandoMix3.vae.pt
elif Model=="Riffusion v1":
    # !git clone https://github.com/enlyth/sd-webui-riffusion /content/stable-diffusion-webui/extensions/sd-webui-riffusion
    # !rm /content/stable-diffusion-webui/extensions/sd-webui-riffusion/install.py /content/stable-diffusion-webui/extensions/sd-webui-riffusion/requirements.txt
    # !pip -q install pedalboard
    # !wget https://huggingface.co/ckpt/riffusion-model-v1/resolve/main/riffusion-model-v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/riffusion-model-v1.ckpt
elif Model=="RPG v4":
    # !wget https://huggingface.co/Anashel/rpg/resolve/main/RPG-V4-Model-Download/RPG-v4.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/RPG-v4.safetensors
    # !wget https://huggingface.co/Anashel/rpg/raw/main/RPG-V4-Model-Download/RPG-v4.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/RPG-v4.yaml
    # !wget https://huggingface.co/Anashel/rpg/resolve/main/RPG-VAE-Current-Download/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/RPG-v4.vae.pt
elif Model=="SamDoesArt Diffusion":
    # !wget https://huggingface.co/ckpt/SamDoesArt-V3/resolve/main/SamDoesArt-V3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SamDoesArt-V3.ckpt
elif Model=="SamDoesSexy Blend":
    # !wget https://huggingface.co/ckpt/samdoessexy-blend/resolve/main/samdoessexyBlend.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/samdoessexyBlend.safetensors
elif Model=="Seek Art Mega v1":
    # !wget https://huggingface.co/ckpt/seek.art_MEGA/resolve/main/seek_art_mega_v1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/seek_art_mega_v1.ckpt
elif Model=="Simpmaker 3k":
    # !wget https://huggingface.co/ckpt/SimpMaker-3K1/resolve/main/SimpMaker%203k.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SimpMaker%203k.ckpt
    # !wget https://huggingface.co/ckpt/SimpMaker-3K1/resolve/main/SimpMaker%203k1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SimpMaker%203k1.ckpt
    # !wget https://huggingface.co/ckpt/SimpMaker-3K1/resolve/main/SimpMaker%203k2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SimpMaker%203k2.ckpt
    # !wget https://huggingface.co/ckpt/SimpMaker-3K1/resolve/main/SimpMaker%203k3.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SimpMaker%203k3.ckpt
    # !wget https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SimpMaker%203k.vae.pt
elif Model=="Stable Diffusion 1.4":
    # !wget https://huggingface.co/ckpt/sd14/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
elif Model=="Stable Diffusion 1.5":
    # !wget https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.ckpt
elif Model=="Stable Diffusion 1.5 Inpainting":
    # !wget https://huggingface.co/ckpt/i15/resolve/main/sd-v1-5-inpainting.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt
elif Model=="Stable Diffusion 2":
    # !wget https://huggingface.co/ckpt/stable-diffusion-2/resolve/main/768-v-ema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/768-v-ema.ckpt
    # !wget https://huggingface.co/ckpt/stable-diffusion-2/raw/main/v2-inference-v.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/768-v-ema.yaml
elif Model=="Stable Diffusion 2 Base":
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-base/resolve/main/512-base-ema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/512-base-ema.ckpt
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-base/raw/main/v2-inference.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/512-base-ema.yaml
elif Model=="Stable Diffusion 2 Depth":
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-depth/resolve/main/512-depth-ema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/512-depth-ema.ckpt
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-depth/raw/main/v2-midas-inference.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/512-depth-ema.yaml
    # !sed -i -e '/emb = emb.unsqueeze(0)/a\                name = list(data.keys())[0]' /content/stable-diffusion-webui/modules/textual_inversion/textual_inversion.py
    # !wget https://huggingface.co/spaablauw/FloralMarble/resolve/main/FloralMarble-400.pt -O /content/stable-diffusion-webui/embeddings/FloralMarble-400.pt
elif Model=="Stable Diffusion 2 Inpainting":
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-inpainting/resolve/main/512-inpainting-ema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/512-inpainting-ema.ckpt
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-inpainting/raw/main/v2-inpainting-inference.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/512-inpainting-ema.yaml
elif Model=="Stable Diffusion 2.1":
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.ckpt
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-1/raw/main/v2-inference-v.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.yaml
    # !wget https://huggingface.co/joachimsallstrom/Double-Exposure-Embedding/resolve/main/dblx.pt -O /content/stable-diffusion-webui/embeddings/dblx.pt
    # !wget https://huggingface.co/Conflictx/AnimeScreencap/resolve/main/AnimeScreenCap.pt -O /content/stable-diffusion-webui/embeddings/AnimeScreenCap.pt
elif Model=="Stable Diffusion 2.1 Base":
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1_512-ema-pruned.ckpt
    # !wget https://huggingface.co/ckpt/stable-diffusion-2-1-base/raw/main/v2-inference.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1_512-ema-pruned.yaml
elif Model=="Synthwave Punk v2":
    # !wget https://huggingface.co/ckpt/SynthwavePunk-v2/resolve/main/SynthwavePunk-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/SynthwavePunk-v2.ckpt
elif Model=="Uber Realistic v1":
    # !wget https://huggingface.co/ckpt/urp/resolve/main/uberRealisticPornMer_urpMv1_ema.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/uberRealisticPornMer_urpMv1_ema.ckpt
    # !wget https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/uberRealisticPornMer_urpMv1_ema.vae.pt
elif Model=="Van Gogh Diffusion":
    # !wget https://huggingface.co/ckpt/Van-Gogh-diffusion/resolve/main/Van-Gogh-Style-lvngvncnt-v2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Van-Gogh-Style-lvngvncnt-v2.ckpt
elif Model=="Vintedois Diffusion":
    # !wget https://huggingface.co/ckpt/vintedois-diffusion-v0-1/resolve/main/vintedois_0_1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/vintedois_0_1.ckpt
elif Model=="Waifu Diffusion":
    # !wget https://huggingface.co/ckpt/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/wd-v1-3-float32.ckpt
    # !wget https://huggingface.co/ckpt/waifu-diffusion-v1-4/resolve/main/kl-f8-anime2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/wd-v1-3-float32.vae.pt
elif Model=="Waifu Diffusion 1.4":
    # !wget https://huggingface.co/ckpt/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e1.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/wd-1-4-anime_e1.ckpt
    # !wget https://huggingface.co/ckpt/waifu-diffusion-v1-4/raw/main/wd-1-4-anime_e1.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/wd-1-4-anime_e1.yaml
elif Model=="Woolitize":
    # !wget https://huggingface.co/ckpt/woolitize/resolve/main/woolitize.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/woolitize.ckpt
elif Model=="Yiffy E18":
    # !wget https://huggingface.co/ckpt/yiffy-e18/resolve/main/yiffy-e18.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffy-e18.ckpt
elif Model=="Yiffy Mix":
    # !wget https://huggingface.co/ckpt/yiffymix/resolve/main/yiffymix.safetensors -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffymix.safetensors
    # !wget https://huggingface.co/ckpt/waifu-diffusion-v1-4/resolve/main/kl-f8-anime2.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/yiffymix.vae.pt
elif Model=="Yohan Diffusion":
    # !wget https://huggingface.co/ckpt/yohan-diffusion/resolve/main/yohan-diffusion.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/yohan-diffusion.ckpt
    # !wget https://huggingface.co/ckpt/anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/yohan-diffusion.vae.pt
    # !wget https://huggingface.co/ckpt/yohan-diffusion/resolve/main/Cocoa.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/Cocoa.ckpt
else:          
    # !wget https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/v1-5-pruned-emaonly.ckpt

## Downloading requested embeddings

if bad_artist:
    # !wget https://huggingface.co/nick-x-hacker/bad-artist/resolve/main/bad-artist-anime.pt -O /content/stable-diffusion-webui/embeddings/bad-artist-anime.pt
if bad_artist_anime:
    # !wget https://huggingface.co/nick-x-hacker/bad-artist/resolve/main/bad-artist.pt -O /content/stable-diffusion-webui/embeddings/bad-artist.pt
if bad_hands_5:
    # !wget https://huggingface.co/yesyeahvh/bad-hands-5/resolve/main/bad-hands-5.pt -O /content/stable-diffusion-webui/embeddings/bad-hands-5.pt
if bad_prompt:
    # !wget https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt.pt -O /content/stable-diffusion-webui/embeddings/bad_prompt.pt
if bad_prompt_version2:
    # !wget https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt -O /content/stable-diffusion-webui/embeddings/bad_prompt_version2.pt

## Downloading requested VAE

if Anything_V3_vae:
    # !wget https://huggingface.co/Maseshi/Anything-v3.0/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/VAE/Anything-V3.0.vae.pt
if vae_ft_mse_840000_ema_pruned:
    # !wget https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors -O /content/stable-diffusion-webui/models/VAE/vae-ft-mse-840000-ema-pruned.safetensors

## Launching environment

# !sed -i -e '''/prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/stable-diffusion-webui/launch.py
# !sed -i '$a fastapi==0.90.0' requirements_versions.txt
# !python launch.py --share --xformers --enable-insecure-extension-access --gradio-queue

# %%
#@title Reconnect
#@markdown In case the above cell stop running, if gradio loses connection to Colab, or if you unintentionally refresh this page, use this cell to re-enact your environment without reinstalling everything. You will find your work intact.
# %cd /content/stable-diffusion-webui
# !python launch.py --share --xformers --enable-insecure-extension-access --gradio-queue
